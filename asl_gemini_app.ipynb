# %%
# !pip install google-genai
# !pip install google-generativeai gradio numpy opencv-python
# Out:
# Requirement already satisfied: google-genai in c:\users\tebogo\anaconda3\lib\site-packages (1.19.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\users\tebogo\anaconda3\lib\site-packages (from google-genai) (4.9.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in c:\users\tebogo\anaconda3\lib\site-packages (from google-genai) (2.40.3)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\users\tebogo\anaconda3\lib\site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\users\tebogo\anaconda3\lib\site-packages (from google-genai) (2.8.2)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\users\tebogo\anaconda3\lib\site-packages (from google-genai) (2.32.3)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in c:\users\tebogo\anaconda3\lib\site-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in c:\users\tebogo\anaconda3\lib\site-packages (from google-genai) (4.11.0)
# Requirement already satisfied: idna>=2.8 in c:\users\tebogo\anaconda3\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\tebogo\anaconda3\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (1.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\tebogo\anaconda3\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\tebogo\anaconda3\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\tebogo\anaconda3\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (4.9.1)
# Requirement already satisfied: certifi in c:\users\tebogo\anaconda3\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\tebogo\anaconda3\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\tebogo\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\tebogo\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\tebogo\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tebogo\anaconda3\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tebogo\anaconda3\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.2.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\tebogo\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-genai) (0.4.8)
# Requirement already satisfied: google-generativeai in c:\users\tebogo\anaconda3\lib\site-packages (0.8.5)
# Collecting gradio
#   Downloading gradio-5.33.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: numpy in c:\users\tebogo\anaconda3\lib\site-packages (1.26.4)
# Collecting opencv-python
#   Downloading opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\users\tebogo\anaconda3\lib\site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in c:\users\tebogo\anaconda3\lib\site-packages (from google-generativeai) (2.25.0)
# Requirement already satisfied: google-api-python-client in c:\users\tebogo\anaconda3\lib\site-packages (from google-generativeai) (2.171.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\tebogo\anaconda3\lib\site-packages (from google-generativeai) (2.40.3)
# Requirement already satisfied: protobuf in c:\users\tebogo\anaconda3\lib\site-packages (from google-generativeai) (5.29.5)
# Requirement already satisfied: pydantic in c:\users\tebogo\anaconda3\lib\site-packages (from google-generativeai) (2.8.2)
# Requirement already satisfied: tqdm in c:\users\tebogo\anaconda3\lib\site-packages (from google-generativeai) (4.66.5)
# Requirement already satisfied: typing-extensions in c:\users\tebogo\anaconda3\lib\site-packages (from google-generativeai) (4.11.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\tebogo\anaconda3\lib\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Collecting aiofiles<25.0,>=22.0 (from gradio)
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\tebogo\anaconda3\lib\site-packages (from gradio) (4.9.0)
# Collecting fastapi<1.0,>=0.115.2 (from gradio)
#   Downloading fastapi-0.115.12-py3-none-any.whl.metadata (27 kB)
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-0.6.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting gradio-client==1.10.2 (from gradio)
#   Downloading gradio_client-1.10.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio)
#   Downloading groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\tebogo\anaconda3\lib\site-packages (from gradio) (0.28.1)
# Collecting huggingface-hub>=0.28.1 (from gradio)
#   Downloading huggingface_hub-0.32.4-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: jinja2<4.0 in c:\users\tebogo\anaconda3\lib\site-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\tebogo\anaconda3\lib\site-packages (from gradio) (2.1.3)
# Collecting orjson~=3.0 (from gradio)
#   Downloading orjson-3.10.18-cp312-cp312-win_amd64.whl.metadata (43 kB)
# Requirement already satisfied: packaging in c:\users\tebogo\anaconda3\lib\site-packages (from gradio) (24.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\tebogo\anaconda3\lib\site-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in c:\users\tebogo\anaconda3\lib\site-packages (from gradio) (10.4.0)
# Collecting pydub (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.18 (from gradio)
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\tebogo\anaconda3\lib\site-packages (from gradio) (6.0.1)
# Collecting ruff>=0.9.3 (from gradio)
#   Downloading ruff-0.11.13-py3-none-win_amd64.whl.metadata (26 kB)
# Collecting safehttpx<0.2.0,>=0.1.6 (from gradio)
#   Downloading safehttpx-0.1.6-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Using cached semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<1.0,>=0.40.0 (from gradio)
#   Downloading starlette-0.47.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting tomlkit<0.14.0,>=0.12.0 (from gradio)
#   Downloading tomlkit-0.13.3-py3-none-any.whl.metadata (2.8 kB)
# Collecting typer<1.0,>=0.12 (from gradio)
#   Downloading typer-0.16.0-py3-none-any.whl.metadata (15 kB)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.34.3-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: fsspec in c:\users\tebogo\anaconda3\lib\site-packages (from gradio-client==1.10.2->gradio) (2024.6.1)
# Requirement already satisfied: websockets<16.0,>=10.0 in c:\users\tebogo\anaconda3\lib\site-packages (from gradio-client==1.10.2->gradio) (15.0.1)
# Requirement already satisfied: idna>=2.8 in c:\users\tebogo\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\tebogo\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Collecting starlette<1.0,>=0.40.0 (from gradio)
#   Downloading starlette-0.46.2-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\tebogo\anaconda3\lib\site-packages (from google-api-core->google-generativeai) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\tebogo\anaconda3\lib\site-packages (from google-api-core->google-generativeai) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\tebogo\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\tebogo\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\tebogo\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: certifi in c:\users\tebogo\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\tebogo\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\tebogo\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in c:\users\tebogo\anaconda3\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (3.13.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tebogo\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tebogo\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tebogo\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\tebogo\anaconda3\lib\site-packages (from pydantic->google-generativeai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\tebogo\anaconda3\lib\site-packages (from pydantic->google-generativeai) (2.20.1)
# Requirement already satisfied: colorama in c:\users\tebogo\anaconda3\lib\site-packages (from tqdm->google-generativeai) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\tebogo\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\tebogo\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\tebogo\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.7.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\tebogo\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\tebogo\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\tebogo\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\tebogo\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.72.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\tebogo\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\tebogo\anaconda3\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\tebogo\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.4.8)
# Requirement already satisfied: six>=1.5 in c:\users\tebogo\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tebogo\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tebogo\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2.2.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\tebogo\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\tebogo\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\tebogo\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)
# Downloading gradio-5.33.0-py3-none-any.whl (54.2 MB)
#    ---------------------------------------- 0.0/54.2 MB ? eta -:--:--
#    - -------------------------------------- 1.8/54.2 MB 11.2 MB/s eta 0:00:05
#    --- ------------------------------------ 4.5/54.2 MB 10.8 MB/s eta 0:00:05
#    ----- ---------------------------------- 7.3/54.2 MB 11.6 MB/s eta 0:00:05
#    ------- -------------------------------- 9.7/54.2 MB 11.6 MB/s eta 0:00:04
#    -------- ------------------------------- 11.8/54.2 MB 11.4 MB/s eta 0:00:04
#    ---------- ----------------------------- 13.9/54.2 MB 10.9 MB/s eta 0:00:04
#    ----------- ---------------------------- 16.3/54.2 MB 10.9 MB/s eta 0:00:04
#    ------------- -------------------------- 17.8/54.2 MB 10.6 MB/s eta 0:00:04
#    -------------- ------------------------- 19.1/54.2 MB 10.1 MB/s eta 0:00:04
#    --------------- ------------------------ 21.2/54.2 MB 10.2 MB/s eta 0:00:04
#    ---------------- ----------------------- 22.8/54.2 MB 9.9 MB/s eta 0:00:04
#    ------------------ --------------------- 24.9/54.2 MB 9.9 MB/s eta 0:00:03
#    -------------------- ------------------- 27.3/54.2 MB 10.0 MB/s eta 0:00:03
#    --------------------- ------------------ 29.4/54.2 MB 10.0 MB/s eta 0:00:03
#    ----------------------- ---------------- 31.5/54.2 MB 9.9 MB/s eta 0:00:03
#    ------------------------ --------------- 33.6/54.2 MB 9.9 MB/s eta 0:00:03
#    ------------------------- -------------- 34.9/54.2 MB 9.8 MB/s eta 0:00:02
#    -------------------------- ------------- 35.9/54.2 MB 9.5 MB/s eta 0:00:02
#    --------------------------- ------------ 37.2/54.2 MB 9.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 38.8/54.2 MB 9.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 40.4/54.2 MB 9.2 MB/s eta 0:00:02
#    ------------------------------ --------- 41.7/54.2 MB 9.1 MB/s eta 0:00:02
#    ------------------------------- -------- 42.7/54.2 MB 8.9 MB/s eta 0:00:02
#    ------------------------------- -------- 43.3/54.2 MB 8.7 MB/s eta 0:00:02
#    -------------------------------- ------- 44.0/54.2 MB 8.5 MB/s eta 0:00:02
#    --------------------------------- ------ 45.6/54.2 MB 8.4 MB/s eta 0:00:02
#    ---------------------------------- ----- 47.2/54.2 MB 8.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 48.5/54.2 MB 8.3 MB/s eta 0:00:01
#    ------------------------------------ --- 50.1/54.2 MB 8.2 MB/s eta 0:00:01
#    ------------------------------------- -- 50.3/54.2 MB 8.2 MB/s eta 0:00:01
#    ------------------------------------- -- 51.1/54.2 MB 7.9 MB/s eta 0:00:01
#    -------------------------------------- - 52.2/54.2 MB 7.8 MB/s eta 0:00:01
#    ---------------------------------------  53.2/54.2 MB 7.7 MB/s eta 0:00:01
#    ---------------------------------------  53.7/54.2 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------  54.0/54.2 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------- 54.2/54.2 MB 7.3 MB/s eta 0:00:00
# Downloading gradio_client-1.10.2-py3-none-any.whl (323 kB)
# Downloading opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl (39.5 MB)
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    - -------------------------------------- 1.6/39.5 MB 7.6 MB/s eta 0:00:05
#    --- ------------------------------------ 3.1/39.5 MB 7.4 MB/s eta 0:00:05
#    ---- ----------------------------------- 4.7/39.5 MB 7.5 MB/s eta 0:00:05
#    ------ --------------------------------- 6.3/39.5 MB 7.3 MB/s eta 0:00:05
#    ------- -------------------------------- 7.3/39.5 MB 6.9 MB/s eta 0:00:05
#    -------- ------------------------------- 8.7/39.5 MB 6.7 MB/s eta 0:00:05
#    --------- ------------------------------ 9.7/39.5 MB 6.6 MB/s eta 0:00:05
#    ---------- ----------------------------- 10.5/39.5 MB 6.1 MB/s eta 0:00:05
#    ----------- ---------------------------- 11.5/39.5 MB 6.0 MB/s eta 0:00:05
#    ------------ --------------------------- 12.1/39.5 MB 5.8 MB/s eta 0:00:05
#    ------------ --------------------------- 12.6/39.5 MB 5.4 MB/s eta 0:00:05
#    ------------- -------------------------- 12.8/39.5 MB 5.2 MB/s eta 0:00:06
#    ------------- -------------------------- 13.4/39.5 MB 4.9 MB/s eta 0:00:06
#    ------------- -------------------------- 13.6/39.5 MB 4.8 MB/s eta 0:00:06
#    -------------- ------------------------- 14.2/39.5 MB 4.5 MB/s eta 0:00:06
#    --------------- ------------------------ 14.9/39.5 MB 4.4 MB/s eta 0:00:06
#    --------------- ------------------------ 15.7/39.5 MB 4.3 MB/s eta 0:00:06
#    ---------------- ----------------------- 16.0/39.5 MB 4.2 MB/s eta 0:00:06
#    ---------------- ----------------------- 16.3/39.5 MB 4.1 MB/s eta 0:00:06
#    ---------------- ----------------------- 16.8/39.5 MB 3.9 MB/s eta 0:00:06
#    ----------------- ---------------------- 17.6/39.5 MB 3.9 MB/s eta 0:00:06
#    ------------------ --------------------- 18.1/39.5 MB 3.9 MB/s eta 0:00:06
#    ------------------ --------------------- 18.4/39.5 MB 3.7 MB/s eta 0:00:06
#    ------------------- -------------------- 19.1/39.5 MB 3.7 MB/s eta 0:00:06
#    -------------------- ------------------- 20.2/39.5 MB 3.8 MB/s eta 0:00:06
#    --------------------- ------------------ 21.2/39.5 MB 3.8 MB/s eta 0:00:05
#    ---------------------- ----------------- 22.3/39.5 MB 3.9 MB/s eta 0:00:05
#    ----------------------- ---------------- 23.6/39.5 MB 3.9 MB/s eta 0:00:05
#    ------------------------- -------------- 24.9/39.5 MB 4.0 MB/s eta 0:00:04
#    -------------------------- ------------- 26.0/39.5 MB 4.0 MB/s eta 0:00:04
#    -------------------------- ------------- 26.5/39.5 MB 4.0 MB/s eta 0:00:04
#    ---------------------------- ----------- 27.8/39.5 MB 4.0 MB/s eta 0:00:03
#    ----------------------------- ---------- 28.8/39.5 MB 4.1 MB/s eta 0:00:03
#    ------------------------------ --------- 29.6/39.5 MB 4.1 MB/s eta 0:00:03
#    ------------------------------- -------- 30.7/39.5 MB 4.1 MB/s eta 0:00:03
#    -------------------------------- ------- 32.2/39.5 MB 4.2 MB/s eta 0:00:02
#    --------------------------------- ------ 33.6/39.5 MB 4.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 35.1/39.5 MB 4.3 MB/s eta 0:00:02
#    ------------------------------------- -- 36.7/39.5 MB 4.4 MB/s eta 0:00:01
#    -------------------------------------- - 37.7/39.5 MB 4.4 MB/s eta 0:00:01
#    -------------------------------------- - 38.0/39.5 MB 4.4 MB/s eta 0:00:01
#    -------------------------------------- - 38.0/39.5 MB 4.4 MB/s eta 0:00:01
#    -------------------------------------- - 38.3/39.5 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------  38.8/39.5 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  39.3/39.5 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 39.5/39.5 MB 4.1 MB/s eta 0:00:00
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading fastapi-0.115.12-py3-none-any.whl (95 kB)
# Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading huggingface_hub-0.32.4-py3-none-any.whl (512 kB)
# Downloading orjson-3.10.18-cp312-cp312-win_amd64.whl (134 kB)
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading ruff-0.11.13-py3-none-win_amd64.whl (11.5 MB)
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.5 MB 4.8 MB/s eta 0:00:03
#    ------ --------------------------------- 1.8/11.5 MB 5.0 MB/s eta 0:00:02
#    --------- ------------------------------ 2.9/11.5 MB 5.1 MB/s eta 0:00:02
#    -------------- ------------------------- 4.2/11.5 MB 5.5 MB/s eta 0:00:02
#    ------------------- -------------------- 5.5/11.5 MB 5.7 MB/s eta 0:00:02
#    ------------------------ --------------- 7.1/11.5 MB 6.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.4/11.5 MB 6.1 MB/s eta 0:00:01
#    --------------------------------- ------ 9.7/11.5 MB 6.1 MB/s eta 0:00:01
#    ------------------------------------ --- 10.5/11.5 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 5.5 MB/s eta 0:00:00
# Downloading safehttpx-0.1.6-py3-none-any.whl (8.7 kB)
# Using cached semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-0.46.2-py3-none-any.whl (72 kB)
# Downloading tomlkit-0.13.3-py3-none-any.whl (38 kB)
# Downloading typer-0.16.0-py3-none-any.whl (46 kB)
# Downloading uvicorn-0.34.3-py3-none-any.whl (62 kB)
# Downloading ffmpy-0.6.0-py3-none-any.whl (5.5 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub, tomlkit, semantic-version, ruff, python-multipart, orjson, opencv-python, groovy, ffmpy, aiofiles, uvicorn, starlette, huggingface-hub, typer, safehttpx, gradio-client, fastapi, gradio
#   Attempting uninstall: tomlkit
#     Found existing installation: tomlkit 0.11.1
#     Uninstalling tomlkit-0.11.1:
#       Successfully uninstalled tomlkit-0.11.1
#   Attempting uninstall: typer
#     Found existing installation: typer 0.9.0
#     Uninstalling typer-0.9.0:
#       Successfully uninstalled typer-0.9.0
# Successfully installed aiofiles-24.1.0 fastapi-0.115.12 ffmpy-0.6.0 gradio-5.33.0 gradio-client-1.10.2 groovy-0.1.2 huggingface-hub-0.32.4 opencv-python-4.11.0.86 orjson-3.10.18 pydub-0.25.1 python-multipart-0.0.20 ruff-0.11.13 safehttpx-0.1.6 semantic-version-2.10.0 starlette-0.46.2 tomlkit-0.13.3 typer-0.16.0 uvicorn-0.34.3

# %%
# To run this code you need to install the following dependencies:
# pip install google-genai

import base64
import gradio as gr
import google.generativeai as genai
import numpy as np
import cv2

# Configure Gemini API
api_key = "AIzaSyB5fCVl9XTUQfV8qSqJG04MbG2EOGYsXiU"
genai.configure(api_key=api_key)
model = genai.GenerativeModel('gemini-1.5-flash-latest')

def process_image(image):
    """Process image for Gemini API"""
    # Convert Gradio image (numpy array) to bytes
    _, buffer = cv2.imencode('.jpg', image)
    image_bytes = buffer.tobytes()
    
    # Convert to base64
    return base64.b64encode(image_bytes).decode('utf-8')

def recognize_asl(image):
    """Recognize ASL letter from image using Gemini"""
    if image is None:
        return "Please capture an image first"
    
    try:
        # Prepare image and prompt
        base64_image = process_image(image)
        prompt = """
        Identify the American Sign Language (ASL) letter shown in this image. 
        Only respond with the single letter (A, B, C, D, or E) if recognized. 
        If unclear, respond 'Unknown'. 
        Do not include any other text or explanation.
        
        Image:
        """
        
        # Call Gemini API
        response = model.generate_content(
            [prompt, {"mime_type": "image/jpeg", "data": base64_image}],
            stream=False
        )
        
        # Process response
        result = response.text.strip().upper()
        valid_letters = ['A', 'B', 'C', 'D', 'E']
        
        return result if result in valid_letters else "Unknown"
        
    except Exception as e:
        return f"Error: {str(e)}"

# Create Gradio interface
with gr.Blocks() as app:
    gr.Markdown("# 🖐️ ASL Letter Recognition")
    gr.Markdown("Show ASL signs for A, B, C, D, or E")
    
    with gr.Row():
        with gr.Column():
            image_input = gr.Image(sources=["webcam", "upload"], 
                                  label="Capture ASL Sign",
                                  height=300)
            btn = gr.Button("Recognize Letter")
            
        with gr.Column():
            output = gr.Textbox(label="Recognized Letter", 
                               placeholder="Letter will appear here")
            
    examples = gr.Examples(
        examples=["./A_test.jpg", "./B_test.jpg", "./C_test.jpg"],
        inputs=image_input,
        label="Example Images"
    )
    
    btn.click(recognize_asl, inputs=image_input, outputs=output)
    image_input.change(recognize_asl, inputs=image_input, outputs=output)

app.launch(debug=True)
